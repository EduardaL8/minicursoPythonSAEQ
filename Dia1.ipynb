# %%
# !python --version
# Out:
# Python 3.7.13

# %%
string_1 = input( "Informe a string 1: ")
# Out:
# Informe a string 1: amo chocolate

# %%
print (string_1)
# Out:
# amo chocolate

# %%
string_2 = input( "Informe a string 2: ")
# Out:
# Informe a string 2: meu nome é eduarda

# %%
print (len(string_1))
# Out:
# 13

# %%
print (len(string_2))
# Out:
# 18

# %%
len(string_1) == len(string_2)
# Out:
# False

# %%
string_1 == string_2
# Out:
# False

# %%
nome_usuario = input( "Informe seu nome: ")
# Out:
# Informe seu nome: Eduarda

# %%
nome_invertido = nome_usuario[::-1]

# %%
nome_maiusculo = nome_invertido.upper()

# %%
print (nome_maiusculo)
# Out:
# ADRAUDE

# %%
nome = input( "Informe seu nome: ")
# Out:
# Informe seu nome: Eduarda Lozinski

# %%
frase = input ( "Digite uma frase: ")
# Out:
# Digite uma frase: Somos todos pó e sombras

# %%
print (frase[:-4])
# Out:
# Somos todos pó e som

# %%
print (frase.capitalize())
# Out:
# Somos todos pó e sombras

# %%
nome_2 = input( "Digite uma frase: ")
# Out:
# Digite uma frase: o lobo uiva para a lua

# %%
print (nome_2.capitalize())
# Out:
# O lobo uiva para a lua

# %%
print (frase.title())
# Out:
# Somos Todos Pó E Sombras

# %%
print (frase.replace(" ", "_"))
# Out:
# Somos_todos_pó_e_sombras

# %%
print (nome.upper())
# Out:
# EDUARDA LOZINSKI

# %%
a = int(input("Digite o primeiro numero: "))
# Out:
# Digite o primeiro numero: 15

# %%
b = int(input("Digite o segundo numero: "))
# Out:
# Digite o segundo numero: 40

# %%
print (a+b)
# Out:
# 55

# %%
print (a-b)
# Out:
# -25

# %%
print ((a+b)/2)
# Out:
# 27.5

# %%
print (f"a soma das variáveis foi igual a {a+b}")
# Out:
# a soma das variáveis foi igual a 55

# %%
print (f"a subtração das vatiáveis foi igual a {a-b}")
# Out:
# a subtração das vatiáveis foi igual a -25

# %%
print (f"a média das variáveis {a} e {b} foi igual a {(a+b)/2}")
# Out:
# a média das variáveis 15 e 40 foi igual a 27.5

# %%
raio = float(input("Informe o raio do circulo: "))
# Out:
# Informe o raio do circulo: 5

# %%
print (f"A área do circulo é {3.14159*(raio**2)}")
# Out:
# A área do circulo é 78.53975
